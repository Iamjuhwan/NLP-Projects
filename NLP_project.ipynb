# %% [markdown]
# <a href="https://colab.research.google.com/github/Iamjuhwan/NLP-Projects/blob/main/NLP_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NLP Text Preprocessing

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
print("Success")
# Out:
# Success

# %%
# Download required NLTK datasets
nltk.download('stopwords')  # Stopwords list
print("Stopword Downloaded")
nltk.download('punkt')  # Tokenization
print("Punkt Downloaded")
nltk.download('wordnet')  # WordNet for Lemmatization
print("WordNet Downloaded")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# Stopword Downloaded
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Punkt Downloaded
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# WordNet Downloaded

# %% [markdown]
# ## Creating a Large, Diverse Dataset
# Creating a dataset of 50 customer reviews with:
#
#
# *   ✔️ Mixed sentiments (positive, negative, neutral)
#
# *   ✔️ Punctuation and special characters
# *   ✔️ Emojis for expression

# %%
# Sample dataset with 50 diverse reviews
reviews = [
    "I absolutely LOVE this product!! ❤️ It's super efficient and really worth the money. Definitely recommend! 👍",
    "Worst purchase ever... 😡 Waste of money. DO NOT BUY!! Full of issues.",
    "This product does what it says, but nothing special. 🤷‍♂️ It's okay for the price, I guess.",
    "AMAZING quality and fast shipping!!! 🚀🔥 #satisfied #fastdelivery",
    "Terrible! Had high expectations, but it broke in a week. Really disappointed. 😞",
    "This phone is great 📱, but the battery drains too fast. 🔋😕",
    "I love how easy it is to use! 🥰 Definitely a game-changer.",
    "Do not buy this laptop! 👎 It crashes every 10 minutes. So frustrating! 😡",
    "The camera quality is excellent! 📸 Love the night mode. 🌙✨",
    "Meh... the product is just average. 😐 I expected more for this price.",
    "Great customer service! 🙌 They replaced my faulty item within 24 hours.",
    "Horrible experience!! 💔 Received a broken item and no refund.",
    "I use this every day now. Super helpful! ✅",
    "The features are nice, but the software is laggy. 🤦‍♀️ Annoying!",
    "Best investment I've made this year! 🔥🔥",
    "Delivery took 2 months 😤 but the product is okay.",
    "Wouldn't recommend to anyone. Waste of time. 🙅‍♂️",
    "Super happy with my purchase!! 🎉 Everything works perfectly.",
    "This product changed my life. ✨ Absolutely incredible!",
    "Not bad, but also not great. Just okay. 😶",
    "Expected more for the price I paid. 😕",
    "Highly recommended! 👏 Fast shipping and great quality.",
    "This is my third purchase from this store and I'm never disappointed! ❤️",
    "Overpriced and underwhelming. 🫤 Could be better.",
    "Works well, but setup was a nightmare. 🛠️ Took me 2 hours!",
    "Love the design but the materials feel cheap. 🧐",
    "Absolutely worth it!! 💎 Super happy with this purchase.",
    "Stopped working after a month. 😔 Very disappointed.",
    "10/10! Would buy again. ⭐⭐⭐⭐⭐",
    "Disgusting smell 🤢, returned immediately.",
    "Best headphones I’ve ever used! 🎧 Sound quality is top-notch.",
    "Regret buying this. Not as advertised. 😠",
    "It does the job. Nothing exceptional. 🤷",
    "The size is perfect, but the fabric feels cheap. 🏷️",
    "Feels premium! 🔝 Great value for money.",
    "Returned because it didn't fit. 🚚 Hassle-free process.",
    "The manual is useless. Had to figure it out myself. 📖",
    "Why is this so expensive?? 💰 Not worth the price.",
    "Awesome customer support! 🎈 They solved my issue instantly.",
    "Very fragile. Broke after one drop. 🫣",
    "Exactly what I needed! 🎯 Highly recommended.",
    "Didn't expect much, but it exceeded my expectations! 🎊",
    "Scratches easily, but functions well. 🏁",
    "This brand never disappoints! 🏆 Will keep buying.",
    "Fake reviews everywhere. Product is terrible. 😒",
    "No words… just amazing. 🔥🔥🔥",
    "This was a gift and the recipient loved it! 🎁",
    "Cheap plastic, feels like a toy. 😡 Not recommended.",
    "Perfect for my needs. 👍 Would purchase again."
]


#list_syntax = ['element 1', 'element 2', 'element 3', 'element 4']
#list_sytax = [6,3,2,6,8,9,7,6]

# %%
# Convert to DataFrame
df_reviews = pd.DataFrame(reviews, columns=["Review"])

# Display the dataset
df_reviews.head(20)  # Show first 20 rows for preview
# Out:
#                                                Review
# 0   I absolutely LOVE this product!! ❤️ It's super...
# 1   Worst purchase ever... 😡 Waste of money. DO NO...
# 2   This product does what it says, but nothing sp...
# 3   AMAZING quality and fast shipping!!! 🚀🔥 #satis...
# 4   Terrible! Had high expectations, but it broke ...
# 5   This phone is great 📱, but the battery drains ...
# 6   I love how easy it is to use! 🥰 Definitely a g...
# 7   Do not buy this laptop! 👎 It crashes every 10 ...
# 8   The camera quality is excellent! 📸 Love the ni...
# 9   Meh... the product is just average. 😐 I expect...
# 10  Great customer service! 🙌 They replaced my fau...
# 11  Horrible experience!! 💔 Received a broken item...
# 12         I use this every day now. Super helpful! ✅
# 13  The features are nice, but the software is lag...
# 14            Best investment I've made this year! 🔥🔥
# 15  Delivery took 2 months 😤 but the product is okay.
# 16  Wouldn't recommend to anyone. Waste of time. 🙅‍♂️
# 17  Super happy with my purchase!! 🎉 Everything wo...
# 18  This product changed my life. ✨ Absolutely inc...
# 19          Not bad, but also not great. Just okay. 😶

# %% [markdown]
# ## Lowercasing
# ### 📌 Why?
# ### Because NLP models treat "Love" and "love" differently (it is case sensitive) hence standardize text by converting it all to lowercase.

# %%
# Convert text to lowercase
df_reviews["Review_Lowercase"] = df_reviews["Review"].str.lower()

# Display results
df_reviews.head(20)  # Show first 10 rows
# Out:
#                                                Review  \
# 0   I absolutely LOVE this product!! ❤️ It's super...
# 1   Worst purchase ever... 😡 Waste of money. DO NO...
# 2   This product does what it says, but nothing sp...
# 3   AMAZING quality and fast shipping!!! 🚀🔥 #satis...
# 4   Terrible! Had high expectations, but it broke ...
# 5   This phone is great 📱, but the battery drains ...
# 6   I love how easy it is to use! 🥰 Definitely a g...
# 7   Do not buy this laptop! 👎 It crashes every 10 ...
# 8   The camera quality is excellent! 📸 Love the ni...
# 9   Meh... the product is just average. 😐 I expect...
# 10  Great customer service! 🙌 They replaced my fau...
# 11  Horrible experience!! 💔 Received a broken item...
# 12         I use this every day now. Super helpful! ✅
# 13  The features are nice, but the software is lag...
# 14            Best investment I've made this year! 🔥🔥
# 15  Delivery took 2 months 😤 but the product is okay.
# 16  Wouldn't recommend to anyone. Waste of time. 🙅‍♂️
# 17  Super happy with my purchase!! 🎉 Everything wo...
# 18  This product changed my life. ✨ Absolutely inc...
# 19          Not bad, but also not great. Just okay. 😶
#
#                                      Review_Lowercase
# 0   i absolutely love this product!! ❤️ it's super...
# 1   worst purchase ever... 😡 waste of money. do no...
# 2   this product does what it says, but nothing sp...
# 3   amazing quality and fast shipping!!! 🚀🔥 #satis...
# 4   terrible! had high expectations, but it broke ...
# 5   this phone is great 📱, but the battery drains ...
# 6   i love how easy it is to use! 🥰 definitely a g...
# 7   do not buy this laptop! 👎 it crashes every 10 ...
# 8   the camera quality is excellent! 📸 love the ni...
# 9   meh... the product is just average. 😐 i expect...
# 10  great customer service! 🙌 they replaced my fau...
# 11  horrible experience!! 💔 received a broken item...
# 12         i use this every day now. super helpful! ✅
# 13  the features are nice, but the software is lag...
# 14            best investment i've made this year! 🔥🔥
# 15  delivery took 2 months 😤 but the product is okay.
# 16  wouldn't recommend to anyone. waste of time. 🙅‍♂️
# 17  super happy with my purchase!! 🎉 everything wo...
# 18  this product changed my life. ✨ absolutely inc...
# 19          not bad, but also not great. just okay. 😶

# %% [markdown]
# ## Removing Punctuation Marks
# ### 📌 Why?
# ### Punctuation doesn't contribute meaning to most NLP models. Removing punctuation simplifies text without affecting readability.

# %%
# Remove punctuation marks
df_reviews["Review_NoPunctuation"] = df_reviews["Review_Lowercase"].apply(lambda text: re.sub(r'[^\w\s]', '', text))

# Display results
df_reviews.head(20)  # Show first 10 rows
# Out:
#                                                Review  \
# 0   I absolutely LOVE this product!! ❤️ It's super...
# 1   Worst purchase ever... 😡 Waste of money. DO NO...
# 2   This product does what it says, but nothing sp...
# 3   AMAZING quality and fast shipping!!! 🚀🔥 #satis...
# 4   Terrible! Had high expectations, but it broke ...
# 5   This phone is great 📱, but the battery drains ...
# 6   I love how easy it is to use! 🥰 Definitely a g...
# 7   Do not buy this laptop! 👎 It crashes every 10 ...
# 8   The camera quality is excellent! 📸 Love the ni...
# 9   Meh... the product is just average. 😐 I expect...
# 10  Great customer service! 🙌 They replaced my fau...
# 11  Horrible experience!! 💔 Received a broken item...
# 12         I use this every day now. Super helpful! ✅
# 13  The features are nice, but the software is lag...
# 14            Best investment I've made this year! 🔥🔥
# 15  Delivery took 2 months 😤 but the product is okay.
# 16  Wouldn't recommend to anyone. Waste of time. 🙅‍♂️
# 17  Super happy with my purchase!! 🎉 Everything wo...
# 18  This product changed my life. ✨ Absolutely inc...
# 19          Not bad, but also not great. Just okay. 😶
#
#                                      Review_Lowercase  \
# 0   i absolutely love this product!! ❤️ it's super...
# 1   worst purchase ever... 😡 waste of money. do no...
# 2   this product does what it says, but nothing sp...
# 3   amazing quality and fast shipping!!! 🚀🔥 #satis...
# 4   terrible! had high expectations, but it broke ...
# 5   this phone is great 📱, but the battery drains ...
# 6   i love how easy it is to use! 🥰 definitely a g...
# 7   do not buy this laptop! 👎 it crashes every 10 ...
# 8   the camera quality is excellent! 📸 love the ni...
# 9   meh... the product is just average. 😐 i expect...
# 10  great customer service! 🙌 they replaced my fau...
# 11  horrible experience!! 💔 received a broken item...
# 12         i use this every day now. super helpful! ✅
# 13  the features are nice, but the software is lag...
# 14            best investment i've made this year! 🔥🔥
# 15  delivery took 2 months 😤 but the product is okay.
# 16  wouldn't recommend to anyone. waste of time. 🙅‍♂️
# 17  super happy with my purchase!! 🎉 everything wo...
# 18  this product changed my life. ✨ absolutely inc...
# 19          not bad, but also not great. just okay. 😶
#
#                                  Review_NoPunctuation
# 0   i absolutely love this product  its super effi...
# 1   worst purchase ever  waste of money do not buy...
# 2   this product does what it says but nothing spe...
# 3   amazing quality and fast shipping  satisfied f...
# 4   terrible had high expectations but it broke in...
# 5   this phone is great  but the battery drains to...
# 6   i love how easy it is to use  definitely a gam...
# 7   do not buy this laptop  it crashes every 10 mi...
# 8   the camera quality is excellent  love the nigh...
# 9   meh the product is just average  i expected mo...
# 10  great customer service  they replaced my fault...
# 11  horrible experience  received a broken item an...
# 12            i use this every day now super helpful
# 13  the features are nice but the software is lagg...
# 14                best investment ive made this year
# 15    delivery took 2 months  but the product is okay
# 16         wouldnt recommend to anyone waste of time
# 17  super happy with my purchase  everything works...
# 18  this product changed my life  absolutely incre...
# 19              not bad but also not great just okay

# %% [markdown]
# ## Removing Stopwords
# 📌 Why?
# Stopwords (e.g., "is", "the", "of") appear frequently but add little meaning.

# %%
# prompt: Remove Stopwords (e.g., "is", "the", "of") appear frequently but add little meaning.

# Remove stopwords
stop_words = set(stopwords.words('english'))
df_reviews["Review_NoStopwords"] = df_reviews["Review_NoPunctuation"].apply(lambda text: ' '.join([word for word in text.split() if word not in stop_words]))

# Display results
df_reviews.head(20)  # Show first 10 rows
# Out:
#                                                Review  \
# 0   I absolutely LOVE this product!! ❤️ It's super...
# 1   Worst purchase ever... 😡 Waste of money. DO NO...
# 2   This product does what it says, but nothing sp...
# 3   AMAZING quality and fast shipping!!! 🚀🔥 #satis...
# 4   Terrible! Had high expectations, but it broke ...
# 5   This phone is great 📱, but the battery drains ...
# 6   I love how easy it is to use! 🥰 Definitely a g...
# 7   Do not buy this laptop! 👎 It crashes every 10 ...
# 8   The camera quality is excellent! 📸 Love the ni...
# 9   Meh... the product is just average. 😐 I expect...
# 10  Great customer service! 🙌 They replaced my fau...
# 11  Horrible experience!! 💔 Received a broken item...
# 12         I use this every day now. Super helpful! ✅
# 13  The features are nice, but the software is lag...
# 14            Best investment I've made this year! 🔥🔥
# 15  Delivery took 2 months 😤 but the product is okay.
# 16  Wouldn't recommend to anyone. Waste of time. 🙅‍♂️
# 17  Super happy with my purchase!! 🎉 Everything wo...
# 18  This product changed my life. ✨ Absolutely inc...
# 19          Not bad, but also not great. Just okay. 😶
#
#                                      Review_Lowercase  \
# 0   i absolutely love this product!! ❤️ it's super...
# 1   worst purchase ever... 😡 waste of money. do no...
# 2   this product does what it says, but nothing sp...
# 3   amazing quality and fast shipping!!! 🚀🔥 #satis...
# 4   terrible! had high expectations, but it broke ...
# 5   this phone is great 📱, but the battery drains ...
# 6   i love how easy it is to use! 🥰 definitely a g...
# 7   do not buy this laptop! 👎 it crashes every 10 ...
# 8   the camera quality is excellent! 📸 love the ni...
# 9   meh... the product is just average. 😐 i expect...
# 10  great customer service! 🙌 they replaced my fau...
# 11  horrible experience!! 💔 received a broken item...
# 12         i use this every day now. super helpful! ✅
# 13  the features are nice, but the software is lag...
# 14            best investment i've made this year! 🔥🔥
# 15  delivery took 2 months 😤 but the product is okay.
# 16  wouldn't recommend to anyone. waste of time. 🙅‍♂️
# 17  super happy with my purchase!! 🎉 everything wo...
# 18  this product changed my life. ✨ absolutely inc...
# 19          not bad, but also not great. just okay. 😶
#
#                                  Review_NoPunctuation  \
# 0   i absolutely love this product  its super effi...
# 1   worst purchase ever  waste of money do not buy...
# 2   this product does what it says but nothing spe...
# 3   amazing quality and fast shipping  satisfied f...
# 4   terrible had high expectations but it broke in...
# 5   this phone is great  but the battery drains to...
# 6   i love how easy it is to use  definitely a gam...
# 7   do not buy this laptop  it crashes every 10 mi...
# 8   the camera quality is excellent  love the nigh...
# 9   meh the product is just average  i expected mo...
# 10  great customer service  they replaced my fault...
# 11  horrible experience  received a broken item an...
# 12            i use this every day now super helpful
# 13  the features are nice but the software is lagg...
# 14                best investment ive made this year
# 15    delivery took 2 months  but the product is okay
# 16         wouldnt recommend to anyone waste of time
# 17  super happy with my purchase  everything works...
# 18  this product changed my life  absolutely incre...
# 19              not bad but also not great just okay
#
#                                    Review_NoStopwords
# 0   absolutely love product super efficient really...
# 1     worst purchase ever waste money buy full issues
# 2       product says nothing special okay price guess
# 3   amazing quality fast shipping satisfied fastde...
# 4   terrible high expectations broke week really d...
# 5                     phone great battery drains fast
# 6                love easy use definitely gamechanger
# 7     buy laptop crashes every 10 minutes frustrating
# 8            camera quality excellent love night mode
# 9                  meh product average expected price
# 10  great customer service replaced faulty item wi...
# 11    horrible experience received broken item refund
# 12                        use every day super helpful
# 13              features nice software laggy annoying
# 14                      best investment ive made year
# 15                delivery took 2 months product okay
# 16                wouldnt recommend anyone waste time
# 17    super happy purchase everything works perfectly
# 18         product changed life absolutely incredible
# 19                                bad also great okay

# %% [markdown]
# ## Stemming & Lemmatization (Reducing Words to Their Base Form)
# ### 📌 Why this step is important?
# ### Both stemming and lemmatization reduce words to their base form, but they work differently.
# ### This is crucial for NLP models because different word forms (e.g., "running", "ran", "runs") should be treated as the same word.
# ### Example:
# ### Without processing: "He is running and she ran fast"
# ### With stemming: "He is run and she ran fast"
# ### With lemmatization: "He be running and she run fast"

# %%
# prompt: ## 6️⃣ Stemming & Lemmatization (Reducing Words to Their Base Form)
# ### 📌 Why is this step important?
# ### Both stemming and lemmatization reduce words to their base form, but they work differently.
# ### This is crucial for NLP models because different word forms (e.g., "running", "ran", "runs") should be treated as the same word.
# ### Example:
# ### Without processing: "He is running and she ran fast"
# ### With stemming: "He is run and she ran fast"
# ### With lemmatization: "He be running and she run fast"

# Initialize stemmer and lemmatizer
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# Apply stemming
df_reviews["Review_Stemmed"] = df_reviews["Review_NoStopwords"].apply(lambda text: ' '.join([stemmer.stem(word) for word in text.split()]))

# Apply lemmatization
df_reviews["Review_Lemmatized"] = df_reviews["Review_NoStopwords"].apply(lambda text: ' '.join([lemmatizer.lemmatize(word) for word in text.split()]))

# Display results
df_reviews.head(20)  # Show first 20 rows
# Out:
#                                                Review  \
# 0   I absolutely LOVE this product!! ❤️ It's super...
# 1   Worst purchase ever... 😡 Waste of money. DO NO...
# 2   This product does what it says, but nothing sp...
# 3   AMAZING quality and fast shipping!!! 🚀🔥 #satis...
# 4   Terrible! Had high expectations, but it broke ...
# 5   This phone is great 📱, but the battery drains ...
# 6   I love how easy it is to use! 🥰 Definitely a g...
# 7   Do not buy this laptop! 👎 It crashes every 10 ...
# 8   The camera quality is excellent! 📸 Love the ni...
# 9   Meh... the product is just average. 😐 I expect...
# 10  Great customer service! 🙌 They replaced my fau...
# 11  Horrible experience!! 💔 Received a broken item...
# 12         I use this every day now. Super helpful! ✅
# 13  The features are nice, but the software is lag...
# 14            Best investment I've made this year! 🔥🔥
# 15  Delivery took 2 months 😤 but the product is okay.
# 16  Wouldn't recommend to anyone. Waste of time. 🙅‍♂️
# 17  Super happy with my purchase!! 🎉 Everything wo...
# 18  This product changed my life. ✨ Absolutely inc...
# 19          Not bad, but also not great. Just okay. 😶
#
#                                      Review_Lowercase  \
# 0   i absolutely love this product!! ❤️ it's super...
# 1   worst purchase ever... 😡 waste of money. do no...
# 2   this product does what it says, but nothing sp...
# 3   amazing quality and fast shipping!!! 🚀🔥 #satis...
# 4   terrible! had high expectations, but it broke ...
# 5   this phone is great 📱, but the battery drains ...
# 6   i love how easy it is to use! 🥰 definitely a g...
# 7   do not buy this laptop! 👎 it crashes every 10 ...
# 8   the camera quality is excellent! 📸 love the ni...
# 9   meh... the product is just average. 😐 i expect...
# 10  great customer service! 🙌 they replaced my fau...
# 11  horrible experience!! 💔 received a broken item...
# 12         i use this every day now. super helpful! ✅
# 13  the features are nice, but the software is lag...
# 14            best investment i've made this year! 🔥🔥
# 15  delivery took 2 months 😤 but the product is okay.
# 16  wouldn't recommend to anyone. waste of time. 🙅‍♂️
# 17  super happy with my purchase!! 🎉 everything wo...
# 18  this product changed my life. ✨ absolutely inc...
# 19          not bad, but also not great. just okay. 😶
#
#                                  Review_NoPunctuation  \
# 0   i absolutely love this product  its super effi...
# 1   worst purchase ever  waste of money do not buy...
# 2   this product does what it says but nothing spe...
# 3   amazing quality and fast shipping  satisfied f...
# 4   terrible had high expectations but it broke in...
# 5   this phone is great  but the battery drains to...
# 6   i love how easy it is to use  definitely a gam...
# 7   do not buy this laptop  it crashes every 10 mi...
# 8   the camera quality is excellent  love the nigh...
# 9   meh the product is just average  i expected mo...
# 10  great customer service  they replaced my fault...
# 11  horrible experience  received a broken item an...
# 12            i use this every day now super helpful
# 13  the features are nice but the software is lagg...
# 14                best investment ive made this year
# 15    delivery took 2 months  but the product is okay
# 16         wouldnt recommend to anyone waste of time
# 17  super happy with my purchase  everything works...
# 18  this product changed my life  absolutely incre...
# 19              not bad but also not great just okay
#
#                                    Review_NoStopwords  \
# 0   absolutely love product super efficient really...
# 1     worst purchase ever waste money buy full issues
# 2       product says nothing special okay price guess
# 3   amazing quality fast shipping satisfied fastde...
# 4   terrible high expectations broke week really d...
# 5                     phone great battery drains fast
# 6                love easy use definitely gamechanger
# 7     buy laptop crashes every 10 minutes frustrating
# 8            camera quality excellent love night mode
# 9                  meh product average expected price
# 10  great customer service replaced faulty item wi...
# 11    horrible experience received broken item refund
# 12                        use every day super helpful
# 13              features nice software laggy annoying
# 14                      best investment ive made year
# 15                delivery took 2 months product okay
# 16                wouldnt recommend anyone waste time
# 17    super happy purchase everything works perfectly
# 18         product changed life absolutely incredible
# 19                                bad also great okay
#
#                                        Review_Stemmed  \
# 0   absolut love product super effici realli worth...
# 1         worst purchas ever wast money buy full issu
# 2           product say noth special okay price guess
# 3         amaz qualiti fast ship satisfi fastdeliveri
# 4    terribl high expect broke week realli disappoint
# 5                      phone great batteri drain fast
# 6                     love easi use definit gamechang
# 7            buy laptop crash everi 10 minut frustrat
# 8                camera qualiti excel love night mode
# 9                     meh product averag expect price
# 10  great custom servic replac faulti item within ...
# 11           horribl experi receiv broken item refund
# 12                           use everi day super help
# 13                    featur nice softwar laggi annoy
# 14                          best invest ive made year
# 15                 deliveri took 2 month product okay
# 16                  wouldnt recommend anyon wast time
# 17         super happi purchas everyth work perfectli
# 18                  product chang life absolut incred
# 19                                bad also great okay
#
#                                     Review_Lemmatized
# 0   absolutely love product super efficient really...
# 1      worst purchase ever waste money buy full issue
# 2        product say nothing special okay price guess
# 3   amazing quality fast shipping satisfied fastde...
# 4   terrible high expectation broke week really di...
# 5                      phone great battery drain fast
# 6                love easy use definitely gamechanger
# 7        buy laptop crash every 10 minute frustrating
# 8            camera quality excellent love night mode
# 9                  meh product average expected price
# 10  great customer service replaced faulty item wi...
# 11    horrible experience received broken item refund
# 12                        use every day super helpful
# 13               feature nice software laggy annoying
# 14                      best investment ive made year
# 15                 delivery took 2 month product okay
# 16                wouldnt recommend anyone waste time
# 17     super happy purchase everything work perfectly
# 18         product changed life absolutely incredible
# 19                                bad also great okay

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk

# Download WordNet dataset for lemmatization
nltk.download('wordnet')

# Initialize Stemmer and Lemmatizer
ps = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# Test words
words = ["running", "flies", "happiness", "better", "wolves", "studies"]

# Apply Stemming
stemmed_words = [ps.stem(word) for word in words]
print("Stemmed Words:", stemmed_words)

# Apply Lemmatization
lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
print("Lemmatized Words:", lemmatized_words)
# Out:
# Stemmed Words: ['run', 'fli', 'happi', 'better', 'wolv', 'studi']
# Lemmatized Words: ['running', 'fly', 'happiness', 'better', 'wolf', 'study']
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Initialize the Porter Stemmer (for stemming) and WordNet Lemmatizer (for lemmatization)
ps = PorterStemmer()  # Stemming
lemmatizer = WordNetLemmatizer()  # Lemmatization

"""
What is Stemming?
-----------------
- Stemming chops words down to their root form by **removing suffixes**.
- It applies **heuristic rules** rather than a linguistic approach.
- It does NOT always produce a real English word.

Example:
- "running" → "run"
- "happiness" → "happi"
- "better" → "better"  (incorrect, should be "good")

What is Lemmatization?
----------------------
- Lemmatization is **more accurate** than stemming.
- It uses a **dictionary-based approach** to return the correct base form of a word.
- It ensures words are **real** words in the English language.

Example:
- "running" → "run"
- "happiness" → "happiness"  (unchanged because it’s already a base form)
- "better" → "good"  (correctly mapped)
"""

# Function to apply stemming
def apply_stemming(text):
    """
    This function applies stemming to all words in a given text.

    - It splits the sentence into individual words.
    - Each word is reduced to its base form using the Porter Stemmer.
    - The words are then joined back into a processed string.

    Example:
    ----------
    Input  : "running quickly towards happiness"
    Output : "run quickli toward happi"
    """
    return ' '.join(ps.stem(word) for word in text.split())

# %%
# Apply stemming to the reviews
df_reviews["Review_Stemmed"] = df_reviews["Review_NoStopwords"].apply(apply_stemming)

# Display the first 10 rows to observe changes
df_reviews.head(20)
# Out:
#                                                Review  \
# 0   I absolutely LOVE this product!! ❤️ It's super...
# 1   Worst purchase ever... 😡 Waste of money. DO NO...
# 2   This product does what it says, but nothing sp...
# 3   AMAZING quality and fast shipping!!! 🚀🔥 #satis...
# 4   Terrible! Had high expectations, but it broke ...
# 5   This phone is great 📱, but the battery drains ...
# 6   I love how easy it is to use! 🥰 Definitely a g...
# 7   Do not buy this laptop! 👎 It crashes every 10 ...
# 8   The camera quality is excellent! 📸 Love the ni...
# 9   Meh... the product is just average. 😐 I expect...
# 10  Great customer service! 🙌 They replaced my fau...
# 11  Horrible experience!! 💔 Received a broken item...
# 12         I use this every day now. Super helpful! ✅
# 13  The features are nice, but the software is lag...
# 14            Best investment I've made this year! 🔥🔥
# 15  Delivery took 2 months 😤 but the product is okay.
# 16  Wouldn't recommend to anyone. Waste of time. 🙅‍♂️
# 17  Super happy with my purchase!! 🎉 Everything wo...
# 18  This product changed my life. ✨ Absolutely inc...
# 19          Not bad, but also not great. Just okay. 😶
#
#                                      Review_Lowercase  \
# 0   i absolutely love this product!! ❤️ it's super...
# 1   worst purchase ever... 😡 waste of money. do no...
# 2   this product does what it says, but nothing sp...
# 3   amazing quality and fast shipping!!! 🚀🔥 #satis...
# 4   terrible! had high expectations, but it broke ...
# 5   this phone is great 📱, but the battery drains ...
# 6   i love how easy it is to use! 🥰 definitely a g...
# 7   do not buy this laptop! 👎 it crashes every 10 ...
# 8   the camera quality is excellent! 📸 love the ni...
# 9   meh... the product is just average. 😐 i expect...
# 10  great customer service! 🙌 they replaced my fau...
# 11  horrible experience!! 💔 received a broken item...
# 12         i use this every day now. super helpful! ✅
# 13  the features are nice, but the software is lag...
# 14            best investment i've made this year! 🔥🔥
# 15  delivery took 2 months 😤 but the product is okay.
# 16  wouldn't recommend to anyone. waste of time. 🙅‍♂️
# 17  super happy with my purchase!! 🎉 everything wo...
# 18  this product changed my life. ✨ absolutely inc...
# 19          not bad, but also not great. just okay. 😶
#
#                                  Review_NoPunctuation  \
# 0   i absolutely love this product  its super effi...
# 1   worst purchase ever  waste of money do not buy...
# 2   this product does what it says but nothing spe...
# 3   amazing quality and fast shipping  satisfied f...
# 4   terrible had high expectations but it broke in...
# 5   this phone is great  but the battery drains to...
# 6   i love how easy it is to use  definitely a gam...
# 7   do not buy this laptop  it crashes every 10 mi...
# 8   the camera quality is excellent  love the nigh...
# 9   meh the product is just average  i expected mo...
# 10  great customer service  they replaced my fault...
# 11  horrible experience  received a broken item an...
# 12            i use this every day now super helpful
# 13  the features are nice but the software is lagg...
# 14                best investment ive made this year
# 15    delivery took 2 months  but the product is okay
# 16         wouldnt recommend to anyone waste of time
# 17  super happy with my purchase  everything works...
# 18  this product changed my life  absolutely incre...
# 19              not bad but also not great just okay
#
#                                    Review_NoStopwords  \
# 0   absolutely love product super efficient really...
# 1     worst purchase ever waste money buy full issues
# 2       product says nothing special okay price guess
# 3   amazing quality fast shipping satisfied fastde...
# 4   terrible high expectations broke week really d...
# 5                     phone great battery drains fast
# 6                love easy use definitely gamechanger
# 7     buy laptop crashes every 10 minutes frustrating
# 8            camera quality excellent love night mode
# 9                  meh product average expected price
# 10  great customer service replaced faulty item wi...
# 11    horrible experience received broken item refund
# 12                        use every day super helpful
# 13              features nice software laggy annoying
# 14                      best investment ive made year
# 15                delivery took 2 months product okay
# 16                wouldnt recommend anyone waste time
# 17    super happy purchase everything works perfectly
# 18         product changed life absolutely incredible
# 19                                bad also great okay
#
#                                        Review_Stemmed  \
# 0   absolut love product super effici realli worth...
# 1         worst purchas ever wast money buy full issu
# 2           product say noth special okay price guess
# 3         amaz qualiti fast ship satisfi fastdeliveri
# 4    terribl high expect broke week realli disappoint
# 5                      phone great batteri drain fast
# 6                     love easi use definit gamechang
# 7            buy laptop crash everi 10 minut frustrat
# 8                camera qualiti excel love night mode
# 9                     meh product averag expect price
# 10  great custom servic replac faulti item within ...
# 11           horribl experi receiv broken item refund
# 12                           use everi day super help
# 13                    featur nice softwar laggi annoy
# 14                          best invest ive made year
# 15                 deliveri took 2 month product okay
# 16                  wouldnt recommend anyon wast time
# 17         super happi purchas everyth work perfectli
# 18                  product chang life absolut incred
# 19                                bad also great okay
#
#                                     Review_Lemmatized
# 0   absolutely love product super efficient really...
# 1      worst purchase ever waste money buy full issue
# 2        product say nothing special okay price guess
# 3   amazing quality fast shipping satisfied fastde...
# 4   terrible high expectation broke week really di...
# 5                      phone great battery drain fast
# 6                love easy use definitely gamechanger
# 7        buy laptop crash every 10 minute frustrating
# 8            camera quality excellent love night mode
# 9                  meh product average expected price
# 10  great customer service replaced faulty item wi...
# 11    horrible experience received broken item refund
# 12                        use every day super helpful
# 13               feature nice software laggy annoying
# 14                      best investment ive made year
# 15                 delivery took 2 month product okay
# 16                wouldnt recommend anyone waste time
# 17     super happy purchase everything work perfectly
# 18         product changed life absolutely incredible
# 19                                bad also great okay

# %%
import spacy

# Load English model (after installation)
nlp = spacy.load("en_core_web_sm")

def spacy_lemmatization(text):
    """
    Applies SpaCy lemmatization to a given text.

    - Uses the "en_core_web_sm" model to analyze words.
    - Converts each word to its base form (lemma).
    """
    doc = nlp(text)
    return " ".join([token.lemma_ for token in doc])

# Example usage
print(spacy_lemmatization("wolves better going"))
# Out:
# wolf well go

# %%
import nltk
from nltk.stem import WordNetLemmatizer

# Ensure that WordNet is downloaded
nltk.download('wordnet')

# Initialize the WordNet Lemmatizer
lemmatizer = WordNetLemmatizer()

# Function to apply lemmatization
def apply_lemmatization(text):
    """
    This function applies lemmatization to all words in a given text.

    - It splits the sentence into individual words.
    - Each word is converted to its base form using the WordNet Lemmatizer.
    - The words are then joined back into a processed string.

    Example:
    ----------
    Input  : "wolves better going"
    Output : "wolf good going"  (correct transformations)
    """
    return ' '.join(lemmatizer.lemmatize(word) for word in text.split())

# Apply lemmatization to the reviews
df_reviews["Review_Lemmatized"] = df_reviews["Review_NoStopwords"].apply(apply_lemmatization)

# Display the first 10 rows to observe changes
df_reviews.head(20)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                                                Review  \
# 0   I absolutely LOVE this product!! ❤️ It's super...
# 1   Worst purchase ever... 😡 Waste of money. DO NO...
# 2   This product does what it says, but nothing sp...
# 3   AMAZING quality and fast shipping!!! 🚀🔥 #satis...
# 4   Terrible! Had high expectations, but it broke ...
# 5   This phone is great 📱, but the battery drains ...
# 6   I love how easy it is to use! 🥰 Definitely a g...
# 7   Do not buy this laptop! 👎 It crashes every 10 ...
# 8   The camera quality is excellent! 📸 Love the ni...
# 9   Meh... the product is just average. 😐 I expect...
# 10  Great customer service! 🙌 They replaced my fau...
# 11  Horrible experience!! 💔 Received a broken item...
# 12         I use this every day now. Super helpful! ✅
# 13  The features are nice, but the software is lag...
# 14            Best investment I've made this year! 🔥🔥
# 15  Delivery took 2 months 😤 but the product is okay.
# 16  Wouldn't recommend to anyone. Waste of time. 🙅‍♂️
# 17  Super happy with my purchase!! 🎉 Everything wo...
# 18  This product changed my life. ✨ Absolutely inc...
# 19          Not bad, but also not great. Just okay. 😶
#
#                                      Review_Lowercase  \
# 0   i absolutely love this product!! ❤️ it's super...
# 1   worst purchase ever... 😡 waste of money. do no...
# 2   this product does what it says, but nothing sp...
# 3   amazing quality and fast shipping!!! 🚀🔥 #satis...
# 4   terrible! had high expectations, but it broke ...
# 5   this phone is great 📱, but the battery drains ...
# 6   i love how easy it is to use! 🥰 definitely a g...
# 7   do not buy this laptop! 👎 it crashes every 10 ...
# 8   the camera quality is excellent! 📸 love the ni...
# 9   meh... the product is just average. 😐 i expect...
# 10  great customer service! 🙌 they replaced my fau...
# 11  horrible experience!! 💔 received a broken item...
# 12         i use this every day now. super helpful! ✅
# 13  the features are nice, but the software is lag...
# 14            best investment i've made this year! 🔥🔥
# 15  delivery took 2 months 😤 but the product is okay.
# 16  wouldn't recommend to anyone. waste of time. 🙅‍♂️
# 17  super happy with my purchase!! 🎉 everything wo...
# 18  this product changed my life. ✨ absolutely inc...
# 19          not bad, but also not great. just okay. 😶
#
#                                  Review_NoPunctuation  \
# 0   i absolutely love this product  its super effi...
# 1   worst purchase ever  waste of money do not buy...
# 2   this product does what it says but nothing spe...
# 3   amazing quality and fast shipping  satisfied f...
# 4   terrible had high expectations but it broke in...
# 5   this phone is great  but the battery drains to...
# 6   i love how easy it is to use  definitely a gam...
# 7   do not buy this laptop  it crashes every 10 mi...
# 8   the camera quality is excellent  love the nigh...
# 9   meh the product is just average  i expected mo...
# 10  great customer service  they replaced my fault...
# 11  horrible experience  received a broken item an...
# 12            i use this every day now super helpful
# 13  the features are nice but the software is lagg...
# 14                best investment ive made this year
# 15    delivery took 2 months  but the product is okay
# 16         wouldnt recommend to anyone waste of time
# 17  super happy with my purchase  everything works...
# 18  this product changed my life  absolutely incre...
# 19              not bad but also not great just okay
#
#                                    Review_NoStopwords  \
# 0   absolutely love product super efficient really...
# 1     worst purchase ever waste money buy full issues
# 2       product says nothing special okay price guess
# 3   amazing quality fast shipping satisfied fastde...
# 4   terrible high expectations broke week really d...
# 5                     phone great battery drains fast
# 6                love easy use definitely gamechanger
# 7     buy laptop crashes every 10 minutes frustrating
# 8            camera quality excellent love night mode
# 9                  meh product average expected price
# 10  great customer service replaced faulty item wi...
# 11    horrible experience received broken item refund
# 12                        use every day super helpful
# 13              features nice software laggy annoying
# 14                      best investment ive made year
# 15                delivery took 2 months product okay
# 16                wouldnt recommend anyone waste time
# 17    super happy purchase everything works perfectly
# 18         product changed life absolutely incredible
# 19                                bad also great okay
#
#                                        Review_Stemmed  \
# 0   absolut love product super effici realli worth...
# 1         worst purchas ever wast money buy full issu
# 2           product say noth special okay price guess
# 3         amaz qualiti fast ship satisfi fastdeliveri
# 4    terribl high expect broke week realli disappoint
# 5                      phone great batteri drain fast
# 6                     love easi use definit gamechang
# 7            buy laptop crash everi 10 minut frustrat
# 8                camera qualiti excel love night mode
# 9                     meh product averag expect price
# 10  great custom servic replac faulti item within ...
# 11           horribl experi receiv broken item refund
# 12                           use everi day super help
# 13                    featur nice softwar laggi annoy
# 14                          best invest ive made year
# 15                 deliveri took 2 month product okay
# 16                  wouldnt recommend anyon wast time
# 17         super happi purchas everyth work perfectli
# 18                  product chang life absolut incred
# 19                                bad also great okay
#
#                                     Review_Lemmatized
# 0   absolutely love product super efficient really...
# 1      worst purchase ever waste money buy full issue
# 2        product say nothing special okay price guess
# 3   amazing quality fast shipping satisfied fastde...
# 4   terrible high expectation broke week really di...
# 5                      phone great battery drain fast
# 6                love easy use definitely gamechanger
# 7        buy laptop crash every 10 minute frustrating
# 8            camera quality excellent love night mode
# 9                  meh product average expected price
# 10  great customer service replaced faulty item wi...
# 11    horrible experience received broken item refund
# 12                        use every day super helpful
# 13               feature nice software laggy annoying
# 14                      best investment ive made year
# 15                 delivery took 2 month product okay
# 16                wouldnt recommend anyone waste time
# 17     super happy purchase everything work perfectly
# 18         product changed life absolutely incredible
# 19                                bad also great okay

# %%
# prompt: Using dataframe df_reviews: how do i fully view the content of each cell as they are review which make the cell content longer

import pandas as pd

# Set the maximum column width to display the full content of each cell
pd.set_option('display.max_colwidth', None)

# Display the DataFrame
df_reviews
# Out:
#                                                                                                           Review  \
# 0   I absolutely LOVE this product!! ❤️ It's super efficient and really worth the money. Definitely recommend! 👍
# 1                                          Worst purchase ever... 😡 Waste of money. DO NOT BUY!! Full of issues.
# 2                    This product does what it says, but nothing special. 🤷‍♂️ It's okay for the price, I guess.
# 3                                               AMAZING quality and fast shipping!!! 🚀🔥 #satisfied #fastdelivery
# 4                                Terrible! Had high expectations, but it broke in a week. Really disappointed. 😞
# 5                                                     This phone is great 📱, but the battery drains too fast. 🔋😕
# 6                                                     I love how easy it is to use! 🥰 Definitely a game-changer.
# 7                                       Do not buy this laptop! 👎 It crashes every 10 minutes. So frustrating! 😡
# 8                                                     The camera quality is excellent! 📸 Love the night mode. 🌙✨
# 9                                          Meh... the product is just average. 😐 I expected more for this price.
# 10                                       Great customer service! 🙌 They replaced my faulty item within 24 hours.
# 11                                                 Horrible experience!! 💔 Received a broken item and no refund.
# 12                                                                    I use this every day now. Super helpful! ✅
# 13                                              The features are nice, but the software is laggy. 🤦‍♀️ Annoying!
# 14                                                                       Best investment I've made this year! 🔥🔥
# 15                                                             Delivery took 2 months 😤 but the product is okay.
# 16                                                             Wouldn't recommend to anyone. Waste of time. 🙅‍♂️
# 17                                                  Super happy with my purchase!! 🎉 Everything works perfectly.
# 18                                                        This product changed my life. ✨ Absolutely incredible!
# 19                                                                     Not bad, but also not great. Just okay. 😶
# 20                                                                         Expected more for the price I paid. 😕
# 21                                                        Highly recommended! 👏 Fast shipping and great quality.
# 22                                      This is my third purchase from this store and I'm never disappointed! ❤️
# 23                                                              Overpriced and underwhelming. 🫤 Could be better.
# 24                                                    Works well, but setup was a nightmare. 🛠️ Took me 2 hours!
# 25                                                               Love the design but the materials feel cheap. 🧐
# 26                                                       Absolutely worth it!! 💎 Super happy with this purchase.
# 27                                                           Stopped working after a month. 😔 Very disappointed.
# 28                                                                                 10/10! Would buy again. ⭐⭐⭐⭐⭐
# 29                                                                     Disgusting smell 🤢, returned immediately.
# 30                                                 Best headphones I’ve ever used! 🎧 Sound quality is top-notch.
# 31                                                                      Regret buying this. Not as advertised. 😠
# 32                                                                       It does the job. Nothing exceptional. 🤷
# 33                                                           The size is perfect, but the fabric feels cheap. 🏷️
# 34                                                                       Feels premium! 🔝 Great value for money.
# 35                                                        Returned because it didn't fit. 🚚 Hassle-free process.
# 36                                                         The manual is useless. Had to figure it out myself. 📖
# 37                                                             Why is this so expensive?? 💰 Not worth the price.
# 38                                                   Awesome customer support! 🎈 They solved my issue instantly.
# 39                                                                         Very fragile. Broke after one drop. 🫣
# 40                                                                  Exactly what I needed! 🎯 Highly recommended.
# 41                                                        Didn't expect much, but it exceeded my expectations! 🎊
# 42                                                                       Scratches easily, but functions well. 🏁
# 43                                                             This brand never disappoints! 🏆 Will keep buying.
# 44                                                               Fake reviews everywhere. Product is terrible. 😒
# 45                                                                                   No words… just amazing. 🔥🔥🔥
# 46                                                                 This was a gift and the recipient loved it! 🎁
# 47                                                           Cheap plastic, feels like a toy. 😡 Not recommended.
# 48                                                                 Perfect for my needs. 👍 Would purchase again.
#
#                                                                                                 Review_Lowercase  \
# 0   i absolutely love this product!! ❤️ it's super efficient and really worth the money. definitely recommend! 👍
# 1                                          worst purchase ever... 😡 waste of money. do not buy!! full of issues.
# 2                    this product does what it says, but nothing special. 🤷‍♂️ it's okay for the price, i guess.
# 3                                               amazing quality and fast shipping!!! 🚀🔥 #satisfied #fastdelivery
# 4                                terrible! had high expectations, but it broke in a week. really disappointed. 😞
# 5                                                     this phone is great 📱, but the battery drains too fast. 🔋😕
# 6                                                     i love how easy it is to use! 🥰 definitely a game-changer.
# 7                                       do not buy this laptop! 👎 it crashes every 10 minutes. so frustrating! 😡
# 8                                                     the camera quality is excellent! 📸 love the night mode. 🌙✨
# 9                                          meh... the product is just average. 😐 i expected more for this price.
# 10                                       great customer service! 🙌 they replaced my faulty item within 24 hours.
# 11                                                 horrible experience!! 💔 received a broken item and no refund.
# 12                                                                    i use this every day now. super helpful! ✅
# 13                                              the features are nice, but the software is laggy. 🤦‍♀️ annoying!
# 14                                                                       best investment i've made this year! 🔥🔥
# 15                                                             delivery took 2 months 😤 but the product is okay.
# 16                                                             wouldn't recommend to anyone. waste of time. 🙅‍♂️
# 17                                                  super happy with my purchase!! 🎉 everything works perfectly.
# 18                                                        this product changed my life. ✨ absolutely incredible!
# 19                                                                     not bad, but also not great. just okay. 😶
# 20                                                                         expected more for the price i paid. 😕
# 21                                                        highly recommended! 👏 fast shipping and great quality.
# 22                                      this is my third purchase from this store and i'm never disappointed! ❤️
# 23                                                              overpriced and underwhelming. 🫤 could be better.
# 24                                                    works well, but setup was a nightmare. 🛠️ took me 2 hours!
# 25                                                               love the design but the materials feel cheap. 🧐
# 26                                                       absolutely worth it!! 💎 super happy with this purchase.
# 27                                                           stopped working after a month. 😔 very disappointed.
# 28                                                                                 10/10! would buy again. ⭐⭐⭐⭐⭐
# 29                                                                     disgusting smell 🤢, returned immediately.
# 30                                                 best headphones i’ve ever used! 🎧 sound quality is top-notch.
# 31                                                                      regret buying this. not as advertised. 😠
# 32                                                                       it does the job. nothing exceptional. 🤷
# 33                                                           the size is perfect, but the fabric feels cheap. 🏷️
# 34                                                                       feels premium! 🔝 great value for money.
# 35                                                        returned because it didn't fit. 🚚 hassle-free process.
# 36                                                         the manual is useless. had to figure it out myself. 📖
# 37                                                             why is this so expensive?? 💰 not worth the price.
# 38                                                   awesome customer support! 🎈 they solved my issue instantly.
# 39                                                                         very fragile. broke after one drop. 🫣
# 40                                                                  exactly what i needed! 🎯 highly recommended.
# 41                                                        didn't expect much, but it exceeded my expectations! 🎊
# 42                                                                       scratches easily, but functions well. 🏁
# 43                                                             this brand never disappoints! 🏆 will keep buying.
# 44                                                               fake reviews everywhere. product is terrible. 😒
# 45                                                                                   no words… just amazing. 🔥🔥🔥
# 46                                                                 this was a gift and the recipient loved it! 🎁
# 47                                                           cheap plastic, feels like a toy. 😡 not recommended.
# 48                                                                 perfect for my needs. 👍 would purchase again.
#
#                                                                                     Review_NoPunctuation  \
# 0   i absolutely love this product  its super efficient and really worth the money definitely recommend
# 1                                          worst purchase ever  waste of money do not buy full of issues
# 2                     this product does what it says but nothing special  its okay for the price i guess
# 3                                              amazing quality and fast shipping  satisfied fastdelivery
# 4                             terrible had high expectations but it broke in a week really disappointed
# 5                                                  this phone is great  but the battery drains too fast
# 6                                                 i love how easy it is to use  definitely a gamechanger
# 7                                    do not buy this laptop  it crashes every 10 minutes so frustrating
# 8                                                  the camera quality is excellent  love the night mode
# 9                                        meh the product is just average  i expected more for this price
# 10                                  great customer service  they replaced my faulty item within 24 hours
# 11                                             horrible experience  received a broken item and no refund
# 12                                                               i use this every day now super helpful
# 13                                             the features are nice but the software is laggy  annoying
# 14                                                                   best investment ive made this year
# 15                                                       delivery took 2 months  but the product is okay
# 16                                                            wouldnt recommend to anyone waste of time
# 17                                              super happy with my purchase  everything works perfectly
# 18                                                   this product changed my life  absolutely incredible
# 19                                                                 not bad but also not great just okay
# 20                                                                   expected more for the price i paid
# 21                                                   highly recommended  fast shipping and great quality
# 22                                  this is my third purchase from this store and im never disappointed
# 23                                                         overpriced and underwhelming  could be better
# 24                                                 works well but setup was a nightmare  took me 2 hours
# 25                                                         love the design but the materials feel cheap
# 26                                                   absolutely worth it  super happy with this purchase
# 27                                                      stopped working after a month  very disappointed
# 28                                                                                 1010 would buy again
# 29                                                                disgusting smell  returned immediately
# 30                                              best headphones ive ever used  sound quality is topnotch
# 31                                                                 regret buying this not as advertised
# 32                                                                  it does the job nothing exceptional
# 33                                                       the size is perfect but the fabric feels cheap
# 34                                                                  feels premium  great value for money
# 35                                                     returned because it didnt fit  hasslefree process
# 36                                                    the manual is useless had to figure it out myself
# 37                                                         why is this so expensive  not worth the price
# 38                                              awesome customer support  they solved my issue instantly
# 39                                                                    very fragile broke after one drop
# 40                                                             exactly what i needed  highly recommended
# 41                                                    didnt expect much but it exceeded my expectations
# 42                                                                  scratches easily but functions well
# 43                                                        this brand never disappoints  will keep buying
# 44                                                          fake reviews everywhere product is terrible
# 45                                                                                no words just amazing
# 46                                                           this was a gift and the recipient loved it
# 47                                                       cheap plastic feels like a toy  not recommended
# 48                                                            perfect for my needs  would purchase again
#
#                                                                  Review_NoStopwords  \
# 0   absolutely love product super efficient really worth money definitely recommend
# 1                                   worst purchase ever waste money buy full issues
# 2                                     product says nothing special okay price guess
# 3                              amazing quality fast shipping satisfied fastdelivery
# 4                         terrible high expectations broke week really disappointed
# 5                                                   phone great battery drains fast
# 6                                              love easy use definitely gamechanger
# 7                                   buy laptop crashes every 10 minutes frustrating
# 8                                          camera quality excellent love night mode
# 9                                                meh product average expected price
# 10                      great customer service replaced faulty item within 24 hours
# 11                                  horrible experience received broken item refund
# 12                                                      use every day super helpful
# 13                                            features nice software laggy annoying
# 14                                                    best investment ive made year
# 15                                              delivery took 2 months product okay
# 16                                              wouldnt recommend anyone waste time
# 17                                  super happy purchase everything works perfectly
# 18                                       product changed life absolutely incredible
# 19                                                              bad also great okay
# 20                                                              expected price paid
# 21                                   highly recommended fast shipping great quality
# 22                                       third purchase store im never disappointed
# 23                                            overpriced underwhelming could better
# 24                                          works well setup nightmare took 2 hours
# 25                                                 love design materials feel cheap
# 26                                            absolutely worth super happy purchase
# 27                                               stopped working month disappointed
# 28                                                                   1010 would buy
# 29                                            disgusting smell returned immediately
# 30                             best headphones ive ever used sound quality topnotch
# 31                                                         regret buying advertised
# 32                                                          job nothing exceptional
# 33                                                  size perfect fabric feels cheap
# 34                                                  feels premium great value money
# 35                                            returned didnt fit hasslefree process
# 36                                                            manual useless figure
# 37                                                            expensive worth price
# 38                                  awesome customer support solved issue instantly
# 39                                                           fragile broke one drop
# 40                                                exactly needed highly recommended
# 41                                          didnt expect much exceeded expectations
# 42                                                  scratches easily functions well
# 43                                              brand never disappoints keep buying
# 44                                         fake reviews everywhere product terrible
# 45                                                                    words amazing
# 46                                                             gift recipient loved
# 47                                         cheap plastic feels like toy recommended
# 48                                                     perfect needs would purchase
#
#                                                             Review_Stemmed  \
# 0   absolut love product super effici realli worth money definit recommend
# 1                              worst purchas ever wast money buy full issu
# 2                                product say noth special okay price guess
# 3                              amaz qualiti fast ship satisfi fastdeliveri
# 4                         terribl high expect broke week realli disappoint
# 5                                           phone great batteri drain fast
# 6                                          love easi use definit gamechang
# 7                                 buy laptop crash everi 10 minut frustrat
# 8                                     camera qualiti excel love night mode
# 9                                          meh product averag expect price
# 10                   great custom servic replac faulti item within 24 hour
# 11                                horribl experi receiv broken item refund
# 12                                                use everi day super help
# 13                                         featur nice softwar laggi annoy
# 14                                               best invest ive made year
# 15                                      deliveri took 2 month product okay
# 16                                       wouldnt recommend anyon wast time
# 17                              super happi purchas everyth work perfectli
# 18                                       product chang life absolut incred
# 19                                                     bad also great okay
# 20                                                       expect price paid
# 21                                highli recommend fast ship great qualiti
# 22                                 third purchas store im never disappoint
# 23                                          overpr underwhelm could better
# 24                                    work well setup nightmar took 2 hour
# 25                                           love design materi feel cheap
# 26                                       absolut worth super happi purchas
# 27                                              stop work month disappoint
# 28                                                          1010 would buy
# 29                                             disgust smell return immedi
# 30                       best headphon ive ever use sound qualiti topnotch
# 31                                                     regret buy advertis
# 32                                                         job noth except
# 33                                          size perfect fabric feel cheap
# 34                                           feel premium great valu money
# 35                                      return didnt fit hasslefre process
# 36                                                    manual useless figur
# 37                                                      expens worth price
# 38                               awesom custom support solv issu instantli
# 39                                                   fragil broke one drop
# 40                                           exactli need highli recommend
# 41                                         didnt expect much exceed expect
# 42                                            scratch easili function well
# 43                                         brand never disappoint keep buy
# 44                                   fake review everywher product terribl
# 45                                                               word amaz
# 46                                                        gift recipi love
# 47                                   cheap plastic feel like toy recommend
# 48                                              perfect need would purchas
#
#                                                                   Review_Lemmatized
# 0   absolutely love product super efficient really worth money definitely recommend
# 1                                    worst purchase ever waste money buy full issue
# 2                                      product say nothing special okay price guess
# 3                              amazing quality fast shipping satisfied fastdelivery
# 4                          terrible high expectation broke week really disappointed
# 5                                                    phone great battery drain fast
# 6                                              love easy use definitely gamechanger
# 7                                      buy laptop crash every 10 minute frustrating
# 8                                          camera quality excellent love night mode
# 9                                                meh product average expected price
# 10                       great customer service replaced faulty item within 24 hour
# 11                                  horrible experience received broken item refund
# 12                                                      use every day super helpful
# 13                                             feature nice software laggy annoying
# 14                                                    best investment ive made year
# 15                                               delivery took 2 month product okay
# 16                                              wouldnt recommend anyone waste time
# 17                                   super happy purchase everything work perfectly
# 18                                       product changed life absolutely incredible
# 19                                                              bad also great okay
# 20                                                              expected price paid
# 21                                   highly recommended fast shipping great quality
# 22                                       third purchase store im never disappointed
# 23                                            overpriced underwhelming could better
# 24                                            work well setup nightmare took 2 hour
# 25                                                  love design material feel cheap
# 26                                            absolutely worth super happy purchase
# 27                                               stopped working month disappointed
# 28                                                                   1010 would buy
# 29                                            disgusting smell returned immediately
# 30                              best headphone ive ever used sound quality topnotch
# 31                                                         regret buying advertised
# 32                                                          job nothing exceptional
# 33                                                   size perfect fabric feel cheap
# 34                                                   feel premium great value money
# 35                                            returned didnt fit hasslefree process
# 36                                                            manual useless figure
# 37                                                            expensive worth price
# 38                                  awesome customer support solved issue instantly
# 39                                                           fragile broke one drop
# 40                                                exactly needed highly recommended
# 41                                           didnt expect much exceeded expectation
# 42                                                     scratch easily function well
# 43                                              brand never disappoints keep buying
# 44                                          fake review everywhere product terrible
# 45                                                                     word amazing
# 46                                                             gift recipient loved
# 47                                          cheap plastic feel like toy recommended
# 48                                                      perfect need would purchase

# %%
# Save the DataFrame to a CSV file
df_reviews.to_csv('01_preprocessed_reviews.csv', index=False)

# Download the CSV file (Colab-specific)
from google.colab import files
files.download('01_preprocessed_reviews.csv')
